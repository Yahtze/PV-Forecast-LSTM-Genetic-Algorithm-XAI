# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from time import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
data_src = "solar_data_combined_cleaned.csv"
data_df = pd.read_csv(data_src)

# %%
num_lags = 30
for i in range(1, num_lags + 1):
    data_df[f'GHI_T_{i}'] = data_df['GHI'].shift(i)

# %%
data_df
# Out:
#                    datetime       local_datetime  Year  Month  Day  Hour  \
# 0       2018-01-01 16:30:00  2018-01-01 09:30:00  2018      1    1    16
# 1       2018-01-01 16:40:00  2018-01-01 09:40:00  2018      1    1    16
# 2       2018-01-01 16:50:00  2018-01-01 09:50:00  2018      1    1    16
# 3       2018-01-01 17:00:00  2018-01-01 10:00:00  2018      1    1    17
# 4       2018-01-01 17:10:00  2018-01-01 10:10:00  2018      1    1    17
# ...                     ...                  ...   ...    ...  ...   ...
# 135551  2023-12-31 22:00:00  2023-12-31 15:00:00  2023     12   31    22
# 135552  2023-12-31 22:10:00  2023-12-31 15:10:00  2023     12   31    22
# 135553  2023-12-31 22:20:00  2023-12-31 15:20:00  2023     12   31    22
# 135554  2023-12-31 22:30:00  2023-12-31 15:30:00  2023     12   31    22
# 135555  2023-12-31 22:40:00  2023-12-31 15:40:00  2023     12   31    22
#
#         Minute  Temperature  Alpha    AOD  ...  GHI_T_21  GHI_T_22  GHI_T_23  \
# 0           30         -1.2   1.20  0.021  ...       NaN       NaN       NaN
# 1           40         -0.8   1.20  0.021  ...       NaN       NaN       NaN
# 2           50         -0.3   1.20  0.021  ...       NaN       NaN       NaN
# 3            0          0.1   1.20  0.021  ...       NaN       NaN       NaN
# 4           10          0.5   1.20  0.021  ...       NaN       NaN       NaN
# ...        ...          ...    ...    ...  ...       ...       ...       ...
# 135551       0          3.1   1.15  0.029  ...     347.0     325.0     292.0
# 135552      10          2.8   1.15  0.029  ...     379.0     347.0     325.0
# 135553      20          2.5   1.15  0.029  ...     339.0     379.0     347.0
# 135554      30          2.2   1.15  0.029  ...     377.0     339.0     379.0
# 135555      40          1.8   1.13  0.029  ...     377.0     377.0     339.0
#
#         GHI_T_24  GHI_T_25  GHI_T_26  GHI_T_27  GHI_T_28  GHI_T_29  GHI_T_30
# 0            NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1            NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2            NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3            NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4            NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...          ...       ...       ...       ...       ...       ...       ...
# 135551     268.0     322.0     306.0     296.0     280.0     263.0     244.0
# 135552     292.0     268.0     322.0     306.0     296.0     280.0     263.0
# 135553     325.0     292.0     268.0     322.0     306.0     296.0     280.0
# 135554     347.0     325.0     292.0     268.0     322.0     306.0     296.0
# 135555     379.0     347.0     325.0     292.0     268.0     322.0     306.0
#
# [135556 rows x 58 columns]

# %%
from copy import deepcopy as dc

data = dc(data_df)
data['local_datetime'] = pd.to_datetime(data_df['local_datetime'])
data.set_index('local_datetime', inplace = True)
data.drop('datetime', axis = 1, inplace = True)
data['Target'] = data['GHI'].shift(-2)
data.dropna(inplace = True)

# %%
data
# Out:
#                      Year  Month  Day  Hour  Minute  Temperature  Alpha  \
# local_datetime
# 2018-01-01 14:30:00  2018      1    1    21      30          2.4   1.18
# 2018-01-01 14:40:00  2018      1    1    21      40          2.0   1.17
# 2018-01-01 14:50:00  2018      1    1    21      50          1.6   1.17
# 2018-01-02 07:40:00  2018      1    2    14      40         -7.3   1.17
# 2018-01-02 07:50:00  2018      1    2    14      50         -6.7   1.17
# ...                   ...    ...  ...   ...     ...          ...    ...
# 2023-12-31 14:40:00  2023     12   31    21      40          3.7   1.15
# 2023-12-31 14:50:00  2023     12   31    21      50          3.4   1.15
# 2023-12-31 15:00:00  2023     12   31    22       0          3.1   1.15
# 2023-12-31 15:10:00  2023     12   31    22      10          2.8   1.15
# 2023-12-31 15:20:00  2023     12   31    22      20          2.5   1.15
#
#                        AOD  Asymmetry  Clearsky DHI  ...  GHI_T_22  GHI_T_23  \
# local_datetime                                       ...
# 2018-01-01 14:30:00  0.021       0.62            46  ...     283.0     273.0
# 2018-01-01 14:40:00  0.022       0.62            45  ...     323.0     283.0
# 2018-01-01 14:50:00  0.022       0.62            44  ...     326.0     323.0
# 2018-01-02 07:40:00  0.016       0.62            15  ...     333.0     326.0
# 2018-01-02 07:50:00  0.016       0.62            20  ...     378.0     333.0
# ...                    ...        ...           ...  ...       ...       ...
# 2023-12-31 14:40:00  0.029       0.62            47  ...     268.0     322.0
# 2023-12-31 14:50:00  0.029       0.62            46  ...     292.0     268.0
# 2023-12-31 15:00:00  0.029       0.62            44  ...     325.0     292.0
# 2023-12-31 15:10:00  0.029       0.62            42  ...     347.0     325.0
# 2023-12-31 15:20:00  0.029       0.62            40  ...     379.0     347.0
#
#                      GHI_T_24  GHI_T_25  GHI_T_26  GHI_T_27  GHI_T_28  \
# local_datetime
# 2018-01-01 14:30:00     251.0     253.0     241.0     226.0     204.0
# 2018-01-01 14:40:00     273.0     251.0     253.0     241.0     226.0
# 2018-01-01 14:50:00     283.0     273.0     251.0     253.0     241.0
# 2018-01-02 07:40:00     323.0     283.0     273.0     251.0     253.0
# 2018-01-02 07:50:00     326.0     323.0     283.0     273.0     251.0
# ...                       ...       ...       ...       ...       ...
# 2023-12-31 14:40:00     306.0     296.0     280.0     263.0     244.0
# 2023-12-31 14:50:00     322.0     306.0     296.0     280.0     263.0
# 2023-12-31 15:00:00     268.0     322.0     306.0     296.0     280.0
# 2023-12-31 15:10:00     292.0     268.0     322.0     306.0     296.0
# 2023-12-31 15:20:00     325.0     292.0     268.0     322.0     306.0
#
#                      GHI_T_29  GHI_T_30  Target
# local_datetime
# 2018-01-01 14:30:00     189.0     142.0   145.0
# 2018-01-01 14:40:00     204.0     189.0    34.0
# 2018-01-01 14:50:00     226.0     204.0    57.0
# 2018-01-02 07:40:00     241.0     226.0    83.0
# 2018-01-02 07:50:00     253.0     241.0   110.0
# ...                       ...       ...     ...
# 2023-12-31 14:40:00     246.0     236.0   203.0
# 2023-12-31 14:50:00     244.0     246.0   183.0
# 2023-12-31 15:00:00     263.0     244.0   153.0
# 2023-12-31 15:10:00     280.0     263.0   125.0
# 2023-12-31 15:20:00     296.0     280.0    82.0
#
# [135524 rows x 57 columns]

# %%
corr_matrix = data.corr()
target_corr = corr_matrix['Target'].sort_values(ascending = False)
print(target_corr)
# Out:
# Target                1.000000
# GHI                   0.932436
# GHI_T_1               0.899829
# GHI_T_2               0.864579
# GHI_T_3               0.825928
# GHI_T_4               0.783943
# Clearsky GHI          0.758181
# GHI_T_5               0.738895
# GHI_T_6               0.691125
# GHI_T_7               0.640635
# DNI                   0.609481
# Clearsky DNI          0.602321
# GHI_T_8               0.588117
# GHI_T_9               0.534108
# GHI_T_10              0.479082
# Kcs                   0.461588
# Temperature           0.428357
# GHI_T_11              0.422032
# Clearsky DHI          0.365960
# GHI_T_12              0.364714
# GHI_T_13              0.306818
# GHI_T_14              0.249464
# Hour                  0.226563
# GHI_T_15              0.192298
# DHI                   0.172603
# GHI_T_16              0.136043
# Pressure              0.122020
# GHI_T_17              0.081362
# Alpha                 0.063365
# Wind Speed            0.057008
# Precipitable Water    0.048369
# Dew Point             0.038454
# GHI_T_18              0.028352
# Minute                0.002880
# Day                  -0.001317
# AOD                  -0.012905
# Ozone                -0.018748
# Year                 -0.021373
# GHI_T_19             -0.022087
# Asymmetry            -0.024117
# Month                -0.034774
# GHI_T_20             -0.070605
# Wind Direction       -0.095220
# SSA                  -0.098027
# Surface Albedo       -0.107914
# GHI_T_21             -0.116215
# GHI_T_22             -0.158610
# GHI_T_23             -0.197976
# GHI_T_24             -0.233596
# GHI_T_25             -0.265502
# GHI_T_26             -0.293078
# GHI_T_27             -0.316352
# GHI_T_28             -0.335285
# GHI_T_29             -0.350246
# GHI_T_30             -0.360450
# Relative Humidity    -0.535020
# Solar Zenith Angle   -0.730903
# Name: Target, dtype: float64

# %%
selected_features = target_corr[abs(target_corr) > 0.3].index.tolist()
print(selected_features)
# Out:
# ['Target', 'GHI', 'GHI_T_1', 'GHI_T_2', 'GHI_T_3', 'GHI_T_4', 'Clearsky GHI', 'GHI_T_5', 'GHI_T_6', 'GHI_T_7', 'DNI', 'Clearsky DNI', 'GHI_T_8', 'GHI_T_9', 'GHI_T_10', 'Kcs', 'Temperature', 'GHI_T_11', 'Clearsky DHI', 'GHI_T_12', 'GHI_T_13', 'GHI_T_27', 'GHI_T_28', 'GHI_T_29', 'GHI_T_30', 'Relative Humidity', 'Solar Zenith Angle']

# %%
data = data[selected_features]
print(data.columns)
# Out:
# Index(['Target', 'GHI', 'GHI_T_1', 'GHI_T_2', 'GHI_T_3', 'GHI_T_4',
#        'Clearsky GHI', 'GHI_T_5', 'GHI_T_6', 'GHI_T_7', 'DNI', 'Clearsky DNI',
#        'GHI_T_8', 'GHI_T_9', 'GHI_T_10', 'Kcs', 'Temperature', 'GHI_T_11',
#        'Clearsky DHI', 'GHI_T_12', 'GHI_T_13', 'GHI_T_27', 'GHI_T_28',
#        'GHI_T_29', 'GHI_T_30', 'Relative Humidity', 'Solar Zenith Angle'],
#       dtype='object')

# %%
data
# Out:
#                      Target  GHI  GHI_T_1  GHI_T_2  GHI_T_3  GHI_T_4  \
# local_datetime
# 2018-01-01 14:30:00   145.0  152    179.0    192.0    292.0    327.0
# 2018-01-01 14:40:00    34.0  160    152.0    179.0    192.0    292.0
# 2018-01-01 14:50:00    57.0  145    160.0    152.0    179.0    192.0
# 2018-01-02 07:40:00    83.0   34    145.0    160.0    152.0    179.0
# 2018-01-02 07:50:00   110.0   57     34.0    145.0    160.0    152.0
# ...                     ...  ...      ...      ...      ...      ...
# 2023-12-31 14:40:00   203.0  246    251.0    271.0    241.0    283.0
# 2023-12-31 14:50:00   183.0  227    246.0    251.0    271.0    241.0
# 2023-12-31 15:00:00   153.0  203    227.0    246.0    251.0    271.0
# 2023-12-31 15:10:00   125.0  183    203.0    227.0    246.0    251.0
# 2023-12-31 15:20:00    82.0  153    183.0    203.0    227.0    246.0
#
#                      Clearsky GHI  GHI_T_5  GHI_T_6  GHI_T_7  ...  GHI_T_11  \
# local_datetime                                                ...
# 2018-01-01 14:30:00           328    342.0    359.0    451.0  ...     493.0
# 2018-01-01 14:40:00           305    327.0    342.0    359.0  ...     486.0
# 2018-01-01 14:50:00           282    292.0    327.0    342.0  ...     477.0
# 2018-01-02 07:40:00            34    192.0    292.0    327.0  ...     463.0
# 2018-01-02 07:50:00            57    179.0    192.0    292.0  ...     451.0
# ...                           ...      ...      ...      ...  ...       ...
# 2023-12-31 14:40:00           295    317.0    341.0    346.0  ...     401.0
# 2023-12-31 14:50:00           271    283.0    317.0    341.0  ...     395.0
# 2023-12-31 15:00:00           247    241.0    283.0    317.0  ...     362.0
# 2023-12-31 15:10:00           222    271.0    241.0    283.0  ...     346.0
# 2023-12-31 15:20:00           196    251.0    271.0    241.0  ...     346.0
#
#                      Clearsky DHI  GHI_T_12  GHI_T_13  GHI_T_27  GHI_T_28  \
# local_datetime
# 2018-01-01 14:30:00            46     395.0     502.0     226.0     204.0
# 2018-01-01 14:40:00            45     493.0     395.0     241.0     226.0
# 2018-01-01 14:50:00            44     486.0     493.0     253.0     241.0
# 2018-01-02 07:40:00            15     477.0     486.0     251.0     253.0
# 2018-01-02 07:50:00            20     463.0     477.0     273.0     251.0
# ...                           ...       ...       ...       ...       ...
# 2023-12-31 14:40:00            47     404.0     386.0     263.0     244.0
# 2023-12-31 14:50:00            46     401.0     404.0     280.0     263.0
# 2023-12-31 15:00:00            44     395.0     401.0     296.0     280.0
# 2023-12-31 15:10:00            42     362.0     395.0     306.0     296.0
# 2023-12-31 15:20:00            40     346.0     362.0     322.0     306.0
#
#                      GHI_T_29  GHI_T_30  Relative Humidity  Solar Zenith Angle
# local_datetime
# 2018-01-01 14:30:00     189.0     142.0              34.01               71.33
# 2018-01-01 14:40:00     204.0     189.0              41.97               72.47
# 2018-01-01 14:50:00     226.0     204.0              43.18               73.66
# 2018-01-02 07:40:00     241.0     226.0              61.51               87.51
# 2018-01-02 07:50:00     253.0     241.0              58.74               85.97
# ...                       ...       ...                ...                 ...
# 2023-12-31 14:40:00     246.0     236.0              55.02               72.66
# 2023-12-31 14:50:00     244.0     246.0              56.19               73.85
# 2023-12-31 15:00:00     263.0     244.0              57.39               75.10
# 2023-12-31 15:10:00     280.0     263.0              58.62               76.39
# 2023-12-31 15:20:00     296.0     280.0              59.88               77.74
#
# [135524 rows x 27 columns]

# %%
Y = data['Target'].to_numpy()
X = data.drop(['Target'], axis = 1).to_numpy()

# %%
def data_split_scale(X, Y):
  train = int(0.8 * len(X))  # 80% Train
  test = len(X) - train #20% test

  X_train, Y_train = X[:train], Y[:train]
  X_test, Y_test = X[train:], Y[train:]

  X_scaler = MinMaxScaler(feature_range=(-1,1))
  Y_scaler = MinMaxScaler(feature_range=(-1,1))

  X_train_scaled = X_scaler.fit_transform(X_train)
  X_test_scaled = X_scaler.transform(X_test)

  Y_train_scaled = Y_scaler.fit_transform(Y_train.reshape(-1,1))
  Y_test_scaled = Y_scaler.transform(Y_test.reshape(-1,1))

  print("Shapes:", X_train_scaled.shape, Y_train_scaled.shape, X_test_scaled.shape, Y_test_scaled.shape)

  return X_train_scaled, Y_train_scaled, X_test_scaled, Y_test_scaled, X_scaler, Y_scaler

X_train_scaled, Y_train_scaled, X_test_scaled, Y_test_scaled, X_scaler, Y_scaler = data_split_scale(X, Y)
# Out:
# Shapes: (108419, 26) (108419, 1) (27105, 26) (27105, 1)

# %%
properties = None

# %%
from sklearn.linear_model import LinearRegression

benchmark_model = LinearRegression()

start = time()
benchmark_model.fit(X_train_scaled, Y_train_scaled)
end = time()

# Make predictions
outputs = benchmark_model.predict(X_test_scaled)

# Inverse transform Y_pred and Y_test_df
# Inverse transform Y_test_df and Y_pred (ensure they are 2D)
actual = Y_scaler.inverse_transform(Y_test_scaled.reshape(-1, 1))
outputs = Y_scaler.inverse_transform(outputs.reshape(-1, 1))

training_score = benchmark_model.score(X_train_scaled, Y_train_scaled) * 100
testing_score = benchmark_model.score(X_test_scaled, Y_test_scaled) * 100

print("Regressor fitted in {:.4f} seconds".format(end - start))
print("Score on Training data : {:.4f}%".format(training_score))
print("Score on Testing data : {:.4f}%".format(testing_score))

# Compute error metrics in the original scale
rmse = np.sqrt(mean_squared_error(actual, outputs))
nrmse_mean = rmse / np.mean(actual)
print("RMSE : {:.4f}".format(rmse))
print(f"nRMSE: {nrmse_mean:.4f}")
mae = mean_absolute_error(actual, outputs)
print(f"MAE: {mae:.4f}")

properties = pd.concat(
    [properties, pd.Series(
      {
        "Name": "Linear Regression (Benchmark)",
        "RMSE": round(rmse, 4),
        "nRMSE": round(nrmse_mean, 4),
        "MAE": round(mae, 4),
        "Training Scores": round(training_score, 4),
        "Testing Scores" : round(testing_score, 4),
        "Training Times": end - round(start, 4)

    }
    ).to_frame().T.set_index(["Name"])]
)
# Out:
# Regressor fitted in 0.2736 seconds
# Score on Training data : 88.5648%
# Score on Testing data : 88.9653%
# RMSE : 89.1395
# nRMSE: 0.2161
# MAE: 56.1562

# %%
window = 100  # Adjust window size

# Convert the NumPy arrays to Pandas Series for rolling calculations
actual_series = pd.Series(actual.flatten())  # Flatten to 1D if necessary
outputs_series = pd.Series(outputs.flatten()) # Flatten to 1D if necessary

# Calculate rolling means using Pandas
actual_smooth = actual_series.rolling(window=window).mean()
outputs_smooth = outputs_series.rolling(window=window).mean()

plt.figure(figsize=(12, 6))
plt.plot(actual_smooth, label="Actual (Smoothed)", linestyle="-")
plt.plot(outputs_smooth, label="Predicted (Smoothed)", linestyle="-")
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("Actual vs Predicted (Smoothed Rolling Average)")
plt.legend()
plt.show()

# %%
from sklearn.linear_model import Ridge

benchmark_model = Ridge(alpha = 0.8)

start = time()
benchmark_model.fit(X_train_scaled, Y_train_scaled)
end = time()

# Make predictions
outputs = benchmark_model.predict(X_test_scaled)

# Inverse transform Y_pred and Y_test_df
# Inverse transform Y_test_df and Y_pred (ensure they are 2D)
actual = Y_scaler.inverse_transform(Y_test_scaled.reshape(-1, 1))
outputs = Y_scaler.inverse_transform(outputs.reshape(-1, 1))

training_score = benchmark_model.score(X_train_scaled, Y_train_scaled) * 100
testing_score = benchmark_model.score(X_test_scaled, Y_test_scaled) * 100

print("Regressor fitted in {:.4f} seconds".format(end - start))
print("Score on Training data : {:.4f}%".format(training_score))
print("Score on Testing data : {:.4f}%".format(testing_score))

# Compute error metrics in the original scale
rmse = np.sqrt(mean_squared_error(actual, outputs))
nrmse_mean = rmse / np.mean(actual)
print("RMSE : {:.4f}".format(rmse))
print(f"nRMSE: {nrmse_mean:.4f}")
mae = mean_absolute_error(actual, outputs)
print(f"MAE: {mae:.4f}")

properties = pd.concat(
    [properties, pd.Series(
      {
        "Name": "Ridge Regression",
        "RMSE": round(rmse, 4),
        "nRMSE": round(nrmse_mean, 4),
        "MAE": round(mae, 4),
        "Training Scores": round(training_score, 4),
        "Testing Scores" : round(testing_score, 4),
        "Training Times": end - round(start, 4)

    }
    ).to_frame().T.set_index(["Name"])]
)
# Out:
# Regressor fitted in 0.0772 seconds
# Score on Training data : 88.5648%
# Score on Testing data : 88.9652%
# RMSE : 89.1396
# nRMSE: 0.2161
# MAE: 56.1622

# %%
properties
# Out:
#                                   RMSE   nRMSE      MAE Training Scores  \
# Name
# Linear Regression (Benchmark)  89.1395  0.2161  56.1562         88.5648
# Ridge Regression               89.1396  0.2161  56.1622         88.5648
#
#                               Testing Scores Training Times
# Name
# Linear Regression (Benchmark)        88.9653       0.273561
# Ridge Regression                     88.9652       0.077178

# %%
from sklearn.neighbors import KNeighborsRegressor

benchmark_model = KNeighborsRegressor(n_neighbors = 5, metric = "euclidean", weights = "uniform")
print(benchmark_model)

start = time()
benchmark_model.fit(X_train_scaled, Y_train_scaled)
end = time()

# Make predictions
outputs = benchmark_model.predict(X_test_scaled)

# Inverse transform Y_pred and Y_test_df
# Inverse transform Y_test_df and Y_pred (ensure they are 2D)
actual = Y_scaler.inverse_transform(Y_test_scaled.reshape(-1, 1))
outputs = Y_scaler.inverse_transform(outputs.reshape(-1, 1))

training_score = benchmark_model.score(X_train_scaled, Y_train_scaled) * 100
testing_score = benchmark_model.score(X_test_scaled, Y_test_scaled) * 100

print("Regressor fitted in {:.4f} seconds".format(end - start))
print("Score on Training data : {:.4f}%".format(training_score))
print("Score on Testing data : {:.4f}%".format(testing_score))

# Compute error metrics in the original scale
rmse = np.sqrt(mean_squared_error(actual, outputs))
nrmse_mean = rmse / np.mean(actual)
print("RMSE : {:.4f}".format(rmse))
print(f"nRMSE: {nrmse_mean:.4f}")
mae = mean_absolute_error(actual, outputs)
print(f"MAE: {mae:.4f}")

properties = pd.concat(
    [properties, pd.Series(
      {
        "Name": "KNeighbours Regressor",
        "RMSE": round(rmse, 4),
        "nRMSE": round(nrmse_mean, 4),
        "MAE": round(mae, 4),
        "Training Scores": round(training_score, 4),
        "Testing Scores" : round(testing_score, 4),
        "Training Times": end - round(start, 4)

    }
    ).to_frame().T.set_index(["Name"])]
)
# Out:
# KNeighborsRegressor(metric='euclidean')
# Regressor fitted in 0.0317 seconds
# Score on Training data : 93.2595%
# Score on Testing data : 87.9035%
# RMSE : 93.3295
# nRMSE: 0.2263
# MAE: 54.5259

# %%
window = 100  # Adjust window size

# Convert the NumPy arrays to Pandas Series for rolling calculations
actual_series = pd.Series(actual.flatten())  # Flatten to 1D if necessary
outputs_series = pd.Series(outputs.flatten()) # Flatten to 1D if necessary

# Calculate rolling means using Pandas
actual_smooth = actual_series.rolling(window=window).mean()
outputs_smooth = outputs_series.rolling(window=window).mean()

plt.figure(figsize=(12, 6))
plt.plot(actual_smooth, label="Actual (Smoothed)", linestyle="-")
plt.plot(outputs_smooth, label="Predicted (Smoothed)", linestyle="-")
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("Actual vs Predicted (Smoothed Rolling Average)")
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

benchmark_model = RandomForestRegressor(n_estimators = 125, max_depth = 100, min_samples_split = 4, min_samples_leaf = 4)
print(benchmark_model)

start = time()
Y_train_scaled = Y_train_scaled.ravel()
benchmark_model.fit(X_train_scaled, Y_train_scaled)
end = time()

# Make predictions
outputs = benchmark_model.predict(X_test_scaled)

# Inverse transform Y_pred and Y_test_df
# Inverse transform Y_test_df and Y_pred (ensure they are 2D)
actual = Y_scaler.inverse_transform(Y_test_scaled.reshape(-1, 1))
outputs = Y_scaler.inverse_transform(outputs.reshape(-1, 1))

training_score = benchmark_model.score(X_train_scaled, Y_train_scaled) * 100
testing_score = benchmark_model.score(X_test_scaled, Y_test_scaled) * 100

print("Regressor fitted in {:.2f} seconds".format(end - start))
print("Score on Training data : {:.2f}%".format(training_score))
print("Score on Testing data : {:.2f}%".format(testing_score))

print("Regressor fitted in {:.4f} seconds".format(end - start))
print("Score on Training data : {:.4f}%".format(training_score))
print("Score on Testing data : {:.4f}%".format(testing_score))

# Compute error metrics in the original scale
rmse = np.sqrt(mean_squared_error(actual, outputs))
nrmse_mean = rmse / np.mean(actual)
print("RMSE : {:.4f}".format(rmse))
print(f"nRMSE: {nrmse_mean:.4f}")
mae = mean_absolute_error(actual, outputs)
print(f"MAE: {mae:.4f}")

properties = pd.concat(
    [properties, pd.Series(
      {
        "Name": "RandomForest Regressor",
        "RMSE": round(rmse, 4),
        "nRMSE": round(nrmse_mean, 4),
        "MAE": round(mae, 4),
        "Training Scores": round(training_score, 4),
        "Testing Scores" : round(testing_score, 4),
        "Training Times": end - round(start, 4)

    }
    ).to_frame().T.set_index(["Name"])]
)
# Out:
# RandomForestRegressor(max_depth=100, min_samples_leaf=4, min_samples_split=4,
#                       n_estimators=125)
# Regressor fitted in 433.99 seconds
# Score on Training data : 96.80%
# Score on Testing data : 90.38%
# Regressor fitted in 433.9929 seconds
# Score on Training data : 96.8020%
# Score on Testing data : 90.3803%
# RMSE : 83.2280
# nRMSE: 0.2018
# MAE: 45.7279

# %%
window = 100  # Adjust window size

# Convert the NumPy arrays to Pandas Series for rolling calculations
actual_series = pd.Series(actual.flatten())  # Flatten to 1D if necessary
outputs_series = pd.Series(outputs.flatten()) # Flatten to 1D if necessary

# Calculate rolling means using Pandas
actual_smooth = actual_series.rolling(window=window).mean()
outputs_smooth = outputs_series.rolling(window=window).mean()

plt.figure(figsize=(12, 6))
plt.plot(actual_smooth, label="Actual (Smoothed)", linestyle="-")
plt.plot(outputs_smooth, label="Predicted (Smoothed)", linestyle="-")
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("Actual vs Predicted (Smoothed Rolling Average)")
plt.legend()
plt.show()

# %%
from sklearn.ensemble import GradientBoostingRegressor

benchmark_model = GradientBoostingRegressor(n_estimators = 125, max_depth = 5, min_samples_split = 4, min_samples_leaf = 4)
print(benchmark_model)

start = time()
Y_train_scaled = Y_train_scaled.ravel()
benchmark_model.fit(X_train_scaled, Y_train_scaled)
end = time()

# Make predictions
outputs = benchmark_model.predict(X_test_scaled)

# Inverse transform Y_pred and Y_test_df
# Inverse transform Y_test_df and Y_pred (ensure they are 2D)
actual = Y_scaler.inverse_transform(Y_test_scaled.reshape(-1, 1))
outputs = Y_scaler.inverse_transform(outputs.reshape(-1, 1))

training_score = benchmark_model.score(X_train_scaled, Y_train_scaled) * 100
testing_score = benchmark_model.score(X_test_scaled, Y_test_scaled) * 100

print("Regressor fitted in {:.2f} seconds".format(end - start))
print("Score on Training data : {:.2f}%".format(training_score))
print("Score on Testing data : {:.2f}%".format(testing_score))

print("Regressor fitted in {:.4f} seconds".format(end - start))
print("Score on Training data : {:.4f}%".format(training_score))
print("Score on Testing data : {:.4f}%".format(testing_score))

# Compute error metrics in the original scale
rmse = np.sqrt(mean_squared_error(actual, outputs))
nrmse_mean = rmse / np.mean(actual)
print("RMSE : {:.4f}".format(rmse))
print(f"nRMSE: {nrmse_mean:.4f}")
mae = mean_absolute_error(actual, outputs)
print(f"MAE: {mae:.4f}")

properties = pd.concat(
    [properties, pd.Series(
      {
        "Name": "GradientBoosting Regressor",
        "RMSE": round(rmse, 4),
        "nRMSE": round(nrmse_mean, 4),
        "MAE": round(mae, 4),
        "Training Scores": round(training_score, 4),
        "Testing Scores" : round(testing_score, 4),
        "Training Times": end - round(start, 4)

    }
    ).to_frame().T.set_index(["Name"])]
)
# Out:
# GradientBoostingRegressor(max_depth=5, min_samples_leaf=4, min_samples_split=4,
#                           n_estimators=125)
# Regressor fitted in 150.26 seconds
# Score on Training data : 91.50%
# Score on Testing data : 90.30%
# Regressor fitted in 150.2613 seconds
# Score on Training data : 91.5023%
# Score on Testing data : 90.2999%
# RMSE : 83.5751
# nRMSE: 0.2026
# MAE: 47.5397

# %%
window = 100  # Adjust window size

# Convert the NumPy arrays to Pandas Series for rolling calculations
actual_series = pd.Series(actual.flatten())  # Flatten to 1D if necessary
outputs_series = pd.Series(outputs.flatten()) # Flatten to 1D if necessary

# Calculate rolling means using Pandas
actual_smooth = actual_series.rolling(window=window).mean()
outputs_smooth = outputs_series.rolling(window=window).mean()

plt.figure(figsize=(12, 6))
plt.plot(actual_smooth, label="Actual (Smoothed)", linestyle="-")
plt.plot(outputs_smooth, label="Predicted (Smoothed)", linestyle="-")
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("Actual vs Predicted (Smoothed Rolling Average)")
plt.legend()
plt.show()

# %%
from sklearn.ensemble import ExtraTreesRegressor

benchmark_model = ExtraTreesRegressor(n_estimators = 125, max_depth = 100, min_samples_split = 4, min_samples_leaf = 4)
print(benchmark_model)

start = time()
Y_train_scaled = Y_train_scaled.ravel()
benchmark_model.fit(X_train_scaled, Y_train_scaled)
end = time()

# Make predictions
outputs = benchmark_model.predict(X_test_scaled)

# Inverse transform Y_pred and Y_test_df
# Inverse transform Y_test_df and Y_pred (ensure they are 2D)
actual = Y_scaler.inverse_transform(Y_test_scaled.reshape(-1, 1))
outputs = Y_scaler.inverse_transform(outputs.reshape(-1, 1))

training_score = benchmark_model.score(X_train_scaled, Y_train_scaled) * 100
testing_score = benchmark_model.score(X_test_scaled, Y_test_scaled) * 100

print("Regressor fitted in {:.2f} seconds".format(end - start))
print("Score on Training data : {:.2f}%".format(training_score))
print("Score on Testing data : {:.2f}%".format(testing_score))

print("Regressor fitted in {:.4f} seconds".format(end - start))
print("Score on Training data : {:.4f}%".format(training_score))
print("Score on Testing data : {:.4f}%".format(testing_score))

# Compute error metrics in the original scale
rmse = np.sqrt(mean_squared_error(actual, outputs))
nrmse_mean = rmse / np.mean(actual)
print("RMSE : {:.4f}".format(rmse))
print(f"nRMSE: {nrmse_mean:.4f}")
mae = mean_absolute_error(actual, outputs)
print(f"MAE: {mae:.4f}")

properties = pd.concat(
    [properties, pd.Series(
      {
        "Name": "ExtraTrees Regressor",
        "RMSE": round(rmse, 4),
        "nRMSE": round(nrmse_mean, 4),
        "MAE": round(mae, 4),
        "Training Scores": round(training_score, 4),
        "Testing Scores" : round(testing_score, 4),
        "Training Times": end - round(start, 4)

    }
    ).to_frame().T.set_index(["Name"])]
)
# Out:
# ExtraTreesRegressor(max_depth=100, min_samples_leaf=4, min_samples_split=4,
#                     n_estimators=125)
# Regressor fitted in 75.39 seconds
# Score on Training data : 97.33%
# Score on Testing data : 90.50%
# Regressor fitted in 75.3921 seconds
# Score on Training data : 97.3341%
# Score on Testing data : 90.5032%
# RMSE : 82.6947
# nRMSE: 0.2005
# MAE: 45.2748

# %%
from sklearn.neural_network import MLPRegressor

benchmark_model = MLPRegressor(batch_size = 256, solver = "adam", activation = "relu", max_iter = 300, learning_rate_init = 0.005)
print(benchmark_model)

start = time()
benchmark_model.fit(X_train_scaled, Y_train_scaled)
end = time()

# Make predictions
outputs = benchmark_model.predict(X_test_scaled)

# Inverse transform Y_pred and Y_test_df
# Inverse transform Y_test_df and Y_pred (ensure they are 2D)
actual = Y_scaler.inverse_transform(Y_test_scaled.reshape(-1, 1))
outputs = Y_scaler.inverse_transform(outputs.reshape(-1, 1))

training_score = benchmark_model.score(X_train_scaled, Y_train_scaled) * 100
testing_score = benchmark_model.score(X_test_scaled, Y_test_scaled) * 100

print("Regressor fitted in {:.2f} seconds".format(end - start))
print("Score on Training data : {:.2f}%".format(training_score))
print("Score on Testing data : {:.2f}%".format(testing_score))

print("Regressor fitted in {:.4f} seconds".format(end - start))
print("Score on Training data : {:.4f}%".format(training_score))
print("Score on Testing data : {:.4f}%".format(testing_score))

# Compute error metrics in the original scale
rmse = np.sqrt(mean_squared_error(actual, outputs))
nrmse_mean = rmse / np.mean(actual)
print("RMSE : {:.4f}".format(rmse))
print(f"nRMSE: {nrmse_mean:.4f}")
mae = mean_absolute_error(actual, outputs)
print(f"MAE: {mae:.4f}")

properties = pd.concat(
    [properties, pd.Series(
      {
        "Name": "MLP Regressor",
        "RMSE": round(rmse, 4),
        "nRMSE": round(nrmse_mean, 4),
        "MAE": round(mae, 4),
        "Training Scores": round(training_score, 4),
        "Testing Scores" : round(testing_score, 4),
        "Training Times": end - round(start, 4)

    }
    ).to_frame().T.set_index(["Name"])]
)
# Out:
# MLPRegressor(batch_size=256, learning_rate_init=0.005, max_iter=300)
# Regressor fitted in 10.83 seconds
# Score on Training data : 90.22%
# Score on Testing data : 89.89%
# Regressor fitted in 10.8263 seconds
# Score on Training data : 90.2237%
# Score on Testing data : 89.8942%
# RMSE : 85.3051
# nRMSE: 0.2068
# MAE: 49.3568

# %%
window = 100  # Adjust window size

# Convert the NumPy arrays to Pandas Series for rolling calculations
actual_series = pd.Series(actual.flatten())  # Flatten to 1D if necessary
outputs_series = pd.Series(outputs.flatten()) # Flatten to 1D if necessary

# Calculate rolling means using Pandas
actual_smooth = actual_series.rolling(window=window).mean()
outputs_smooth = outputs_series.rolling(window=window).mean()

plt.figure(figsize=(12, 6))
plt.plot(actual_smooth, label="Actual (Smoothed)", linestyle="-")
plt.plot(outputs_smooth, label="Predicted (Smoothed)", linestyle="-")
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("Actual vs Predicted (Smoothed Rolling Average)")
plt.legend()
plt.show()

# %%
properties
# Out:
#                                   RMSE   nRMSE      MAE Training Scores  \
# Name
# Linear Regression (Benchmark)  89.1395  0.2161  56.1562         88.5648
# Ridge Regression               89.1396  0.2161  56.1622         88.5648
# KNeighbours Regressor          93.3295  0.2263  54.5259         93.2595
# RandomForest Regressor          83.228  0.2018  45.7279          96.802
# GradientBoosting Regressor     83.5751  0.2026  47.5397         91.5023
# ExtraTrees Regressor           82.6947  0.2005  45.2748         97.3341
# MLP Regressor                  85.3051  0.2068  49.3568         90.2237
#
#                               Testing Scores Training Times
# Name
# Linear Regression (Benchmark)        88.9653       0.273561
# Ridge Regression                     88.9652       0.077178
# KNeighbours Regressor                87.9035       0.031736
# RandomForest Regressor               90.3803     433.992936
# GradientBoosting Regressor           90.2999     150.261246
# ExtraTrees Regressor                 90.5032      75.392165
# MLP Regressor                        89.8942      10.826348

# %%
properties.sort_values(by = "nRMSE")
# Out:
#                                   RMSE   nRMSE      MAE Training Scores  \
# Name
# ExtraTrees Regressor           82.6947  0.2005  45.2748         97.3341
# RandomForest Regressor          83.228  0.2018  45.7279          96.802
# GradientBoosting Regressor     83.5751  0.2026  47.5397         91.5023
# MLP Regressor                  85.3051  0.2068  49.3568         90.2237
# Linear Regression (Benchmark)  89.1395  0.2161  56.1562         88.5648
# Ridge Regression               89.1396  0.2161  56.1622         88.5648
# KNeighbours Regressor          93.3295  0.2263  54.5259         93.2595
#
#                               Testing Scores Training Times
# Name
# ExtraTrees Regressor                 90.5032      75.392165
# RandomForest Regressor               90.3803     433.992936
# GradientBoosting Regressor           90.2999     150.261246
# MLP Regressor                        89.8942      10.826348
# Linear Regression (Benchmark)        88.9653       0.273561
# Ridge Regression                     88.9652       0.077178
# KNeighbours Regressor                87.9035       0.031736

# %% [markdown]
# # Performance Of Models

# %%
# Plot to compare thePerformance of Algorithms
sns.set_context("notebook", font_scale=1.7)
plt.figure(figsize=(18,13))

plt.subplot(2,2,1)
plt.title("RMSE Of Regressors (Lesser Is Better)")
properties["RMSE"].plot(kind="barh", color='#4d80b3');
sns.despine(left=True)
plt.tight_layout()


plt.subplot(2,2,2)
plt.title("MAE Of Regressors (Lesser Is Better)")
properties["MAE"].plot(kind="barh", color='#4d80b3');
sns.despine(left=True)
plt.tight_layout()

plt.subplot(2,2,3)
plt.title("Training Time Of Regressors (Lesser Is Better)")
properties["Training Times"].plot(kind="barh", color='#4d80b3');
sns.despine(left=True)
plt.tight_layout()

# %%
sns.set_style('white')
sns.set_context("paper", font_scale=1.3)

ax= properties[["MAE", "RMSE"]].plot(kind="barh", color=['#9491B5', '#685CF4'], title="Performance of Regressor", figsize=(10, 4))
sns.despine(left=True);
plt.tight_layout()

plt.show()

# %% [markdown]
# #Optimizing Best Peforming Model

# %%
from copy import deepcopy as dc

data = dc(data_df)
data['local_datetime'] = pd.to_datetime(data_df['local_datetime'])
data.set_index('local_datetime', inplace = True)
data.drop('datetime', axis = 1, inplace = True)
data['Target'] = data['GHI'].shift(-2)
data.dropna(inplace = True)

# %%
Y = data['Target'].to_numpy()
X = data.drop(['Target'], axis = 1)
featuresTrain = X.columns
X = X.to_numpy()

# %%
def data_split_scale(X, Y):
  train = int(0.8 * len(X))  # 80% Train
  test = len(X) - train #20% test

  X_train, Y_train = X[:train], Y[:train]
  X_test, Y_test = X[train:], Y[train:]

  X_scaler = MinMaxScaler(feature_range=(-1,1))
  Y_scaler = MinMaxScaler(feature_range=(-1,1))

  X_train_scaled = X_scaler.fit_transform(X_train)
  X_test_scaled = X_scaler.transform(X_test)

  Y_train_scaled = Y_scaler.fit_transform(Y_train.reshape(-1,1))
  Y_test_scaled = Y_scaler.transform(Y_test.reshape(-1,1))

  print("Shapes:", X_train_scaled.shape, Y_train_scaled.shape, X_test_scaled.shape, Y_test_scaled.shape)

  return X_train_scaled, Y_train_scaled, X_test_scaled, Y_test_scaled, X_scaler, Y_scaler

X_train_scaled, Y_train_scaled, X_test_scaled, Y_test_scaled, X_scaler, Y_scaler = data_split_scale(X, Y)
# Out:
# Shapes: (108419, 56) (108419, 1) (27105, 56) (27105, 1)

# %%
from sklearn.ensemble import ExtraTreesRegressor

# Train model
etr = ExtraTreesRegressor()
Y_train_scaled = Y_train_scaled.ravel()
etr.fit(X_train_scaled, Y_train_scaled)

# Get feature importance
importances = etr.feature_importances_

# Sort and plot
feat_imp = pd.Series(importances, index=featuresTrain).sort_values(ascending=False)
top_features = feat_imp[feat_imp > 0.01].index
print(top_features)
# Out:
# Index(['GHI', 'GHI_T_1', 'GHI_T_2', 'GHI_T_3', 'Solar Zenith Angle', 'Hour',
#        'Clearsky GHI', 'DNI'],
#       dtype='object')

# %%
X = data[list(top_features)].to_numpy()
X_train_scaled, Y_train_scaled, X_test_scaled, Y_test_scaled, X_scaler, Y_scaler = data_split_scale(X, Y)
# Out:
# Shapes: (108419, 8) (108419, 1) (27105, 8) (27105, 1)

# %%
from sklearn.ensemble import ExtraTreesRegressor

benchmark_model = ExtraTreesRegressor(n_estimators = 125, max_depth = 100, min_samples_split = 4, min_samples_leaf = 4)
print(benchmark_model)

start = time()
Y_train_scaled = Y_train_scaled.ravel()
benchmark_model.fit(X_train_scaled, Y_train_scaled)
end = time()

# Make predictions
outputs = benchmark_model.predict(X_test_scaled)

# Inverse transform Y_pred and Y_test_df
# Inverse transform Y_test_df and Y_pred (ensure they are 2D)
actual = Y_scaler.inverse_transform(Y_test_scaled.reshape(-1, 1))
outputs = Y_scaler.inverse_transform(outputs.reshape(-1, 1))

training_score = benchmark_model.score(X_train_scaled, Y_train_scaled) * 100
testing_score = benchmark_model.score(X_test_scaled, Y_test_scaled) * 100

print("Regressor fitted in {:.4f} seconds".format(end - start))
print("Score on Training data : {:.4f}%".format(training_score))
print("Score on Testing data : {:.4f}%".format(testing_score))

# Compute error metrics in the original scale
rmse = np.sqrt(mean_squared_error(actual, outputs))
nrmse_mean = rmse / np.mean(actual)
print("RMSE : {:.4f}".format(rmse))
print(f"nRMSE: {nrmse_mean:.4f}")
mae = mean_absolute_error(actual, outputs)
print(f"MAE: {mae:.4f}")

properties = pd.concat(
    [properties, pd.Series(
      {
        "Name": "ExtraTrees Regressor (With Feature Selection)",
        "RMSE": round(rmse, 4),
        "nRMSE": round(nrmse_mean, 4),
        "MAE": round(mae, 4),
        "Training Scores": round(training_score, 4),
        "Testing Scores" : round(testing_score, 4),
        "Training Times": end - round(start, 4)

    }
    ).to_frame().T.set_index(["Name"])]
)
# Out:
# ExtraTreesRegressor(max_depth=100, min_samples_leaf=4, min_samples_split=4,
#                     n_estimators=125)
# Regressor fitted in 23.2980 seconds
# Score on Training data : 95.4930%
# Score on Testing data : 90.5715%
# RMSE : 82.3969
# nRMSE: 0.1998
# MAE: 44.8217

# %%
plt.figure(figsize=(10, 6))
feat_imp = feat_imp[feat_imp > 0.01]
feat_imp.plot(kind='bar', color='skyblue')

# Customizing the plot
plt.title('Feature Importance')
plt.xlabel('Features')
plt.ylabel('Importance Score')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.show()

# %%
properties.sort_values(by = "nRMSE")
# Out:
#                                                   RMSE   nRMSE      MAE  \
# Name
# ExtraTrees Regressor (With Feature Selection)  82.3969  0.1998  44.8217
# ExtraTrees Regressor                           82.6947  0.2005  45.2748
# RandomForest Regressor                          83.228  0.2018  45.7279
# GradientBoosting Regressor                     83.5751  0.2026  47.5397
# MLP Regressor                                  85.3051  0.2068  49.3568
# Linear Regression (Benchmark)                  89.1395  0.2161  56.1562
# Ridge Regression                               89.1396  0.2161  56.1622
# KNeighbours Regressor                          93.3295  0.2263  54.5259
#
#                                               Training Scores Testing Scores  \
# Name
# ExtraTrees Regressor (With Feature Selection)          95.493        90.5715
# ExtraTrees Regressor                                  97.3341        90.5032
# RandomForest Regressor                                 96.802        90.3803
# GradientBoosting Regressor                            91.5023        90.2999
# MLP Regressor                                         90.2237        89.8942
# Linear Regression (Benchmark)                         88.5648        88.9653
# Ridge Regression                                      88.5648        88.9652
# KNeighbours Regressor                                 93.2595        87.9035
#
#                                               Training Times
# Name
# ExtraTrees Regressor (With Feature Selection)      23.298029
# ExtraTrees Regressor                               75.392165
# RandomForest Regressor                            433.992936
# GradientBoosting Regressor                        150.261246
# MLP Regressor                                      10.826348
# Linear Regression (Benchmark)                       0.273561
# Ridge Regression                                    0.077178
# KNeighbours Regressor                               0.031736

# %%
properties.to_csv("20_Minutes_Ahead.csv", index = False)
